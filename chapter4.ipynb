# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X=2*np.random.rand(100,1)
y=4+3*X+np.random.rand(100,1)

# %%
X_b=np.c_[np.ones((100,1)),X]
theta_best=np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)

# %%
theta_best
# Out:
# array([[4.4673668 ],
#        [3.05591811]])

# %%
X_new=np.array([[0],[2]])
X_new_b=np.c_[np.ones((2,1)),X_new]

# %%
y_predict=X_new_b.dot(theta_best)
y_predict
# Out:
# array([[ 4.4673668 ],
#        [10.57920302]])

# %%
plt.plot(X_new,y_predict,"r-")
plt.plot(X,y,"b.")

# %%
from sklearn.linear_model import LinearRegression
lin_reg=LinearRegression()
lin_reg.fit(X,y)
lin_reg.intercept_,lin_reg.coef_
# Out:
# (array([4.4673668]), array([[3.05591811]]))

# %% [markdown]
# Batch Gradient Descent

# %%
eta=0.1
n_iterations=1000
m=100
theta=np.random.rand(2,1)
for iterations in range(n_iterations):
    gradients=2/m*X_b.T.dot(X_b.dot(theta)-y)
    theta=theta-eta*gradients

theta
# Out:
# array([[4.4673668 ],
#        [3.05591811]])

# %% [markdown]
# Stotchastic Gradient Descent

# %%
from sklearn.linear_model import SGDRegressor
sgd_reg=SGDRegressor(max_iter=50,penalty=None,eta0=0.1)
sgd_reg.fit(X,y.ravel())
# Out:
# SGDRegressor(eta0=0.1, max_iter=50, penalty=None)

# %%
sgd_reg.intercept_
# Out:
# array([4.45170527])

# %%
sgd_reg.coef_
# Out:
# array([3.0741971])

# %% [markdown]
# Polynomial Regression

# %% [markdown]
# Learning Curves

# %%
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
def plot_learning_curve(model,X,y):
    X_train,X_val,y_train,y_val=train_test_split(X,y,test_size=0.2)
    train_error,val_error=[],[]
    for m in range(1,len(X_train)):
        model.fit(X_train[:m],y_train[:m])
        y_train_predict=model.predict(X_train[:m])
        y_val_predict=model.predict(X_val)
        train_error.append(mean_squared_error(y_train_predict,y_train[:m]))
        val_error.append(mean_squared_error(y_val_predict,y_val))
    plt.plot(np.sqrt(train_error),"r-+",linewidth=2,label="train")
    plt.plot(np.sqrt(val_error),"b-",linewidth=3,label="val")

# %%
from sklearn.linear_model import LinearRegression
len_reg=LinearRegression()
plot_learning_curve(len_reg,X,y)

# %% [markdown]
# Ridge Regression

# %%
from sklearn.linear_model import Ridge
rid_reg=Ridge(alpha=1,solver="cholesky")
rid_reg.fit(X,y)
rid_reg.predict([[1.5]])
# Out:
# array([9.01067978])

# %%
sgd_reg.predict([[1.5]])
# Out:
# array([9.06300093])

# %% [markdown]
# Lasso Regression

# %%
from sklearn.linear_model import Lasso
lasso_reg=Lasso(alpha=0.1)
lasso_reg.fit(X,y)
lasso_reg.predict([[1.5]])
# Out:
# array([8.91488427])

# %% [markdown]
# ### Logistic Regression

# %% [markdown]
# Softmax Regression

# %%
import seaborn as sns 
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
df=sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
encoder=LabelEncoder()
df['species']=encoder.fit_transform(df['species'])

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
df=df[['sepal_length','petal_length','species']]

# %%
df.head()
# Out:
#    sepal_length  petal_length  species
# 0           5.1           1.4        0
# 1           4.9           1.4        0
# 2           4.7           1.3        0
# 3           4.6           1.5        0
# 4           5.0           1.4        0

# %%
X=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
softmax_reg=LogisticRegression(solver="lbfgs")

# %%
softmax_reg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=softmax_reg.predict(X_test)

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9666666666666667

# %%
softmax_reg.predict_proba([[5,8]])
# Out:
# c:\Users\ANANT\OneDrive\Desktop\library\venv\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([[8.47802108e-12, 6.53142019e-06, 9.99993469e-01]])

# %%
softmax_reg.predict([[5,8]])
# Out:
# c:\Users\ANANT\OneDrive\Desktop\library\venv\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([2])
